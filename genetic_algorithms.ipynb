# %% [markdown]
# # Genetic Algorithms

# %% [markdown]
# Genetic algorithms are a special kind of algorithms that "evolve" through the time, I mean, they start with a bunch of possible solutions that are discarded or reconsiderated in base a fit function that determines how good a solution is, an example of a genetic algorithm is **the algorithm of the typing monkeys**
